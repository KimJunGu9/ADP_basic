# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJunGu9/ADP_basic/blob/main/1_3_%EC%A1%B0%EA%B1%B4%EC%97%90_%EB%94%B0%EB%A5%B8_row%2Ccolumn%EC%84%A0%ED%83%9D_%EB%B0%8F_%EC%82%AD%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 조건에 따른 row/column 선택 및 삭제 
# 조건에 따른 row 선택  

# Series boolean selection 활용하기
    
# 조건이 하나일 때 : df[df['컬럼명'] >= 40]
# 조건이 두개 이상 : df[(조건1) & (조건2) & ((조건3) | (조건4)) ]
# 관계연산자의 우선순위를 모른다면 그냥 괄호를 많이 쓸 것

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_t = pd.read_csv('/content/drive/MyDrive/ADP/Part.1/2.데이터_핸들링/data/titanic.csv')

# %%
df_t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male  embark_town
# 0        True  Southampton
# 1       False    Cherbourg
# 2       False  Southampton
# 3       False  Southampton
# 4        True  Southampton

# %%
df_t[df_t['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#      adult_male  embark_town
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 8         False  Southampton
# 9         False    Cherbourg
# ..          ...          ...
# 875       False    Cherbourg
# 879       False    Cherbourg
# 880       False  Southampton
# 887       False  Southampton
# 889        True    Cherbourg
#
# [342 rows x 11 columns]

# %%
df_t['survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: survived, Length: 891, dtype: bool

# %%
# 조건이 여러개  &가 | 보다 우선순위를 가짐 , 조건연산자의 순위를 모를 때에는 괄호로 묶자

df_t[ (df_t["survived"]==1) | (df_t['fare']>30) & (df_t['class']=="First") ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#      adult_male  embark_town
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 6          True  Southampton
# 8         False  Southampton
# ..          ...          ...
# 875       False    Cherbourg
# 879       False    Cherbourg
# 880       False  Southampton
# 887       False  Southampton
# 889        True    Cherbourg
#
# [396 rows x 11 columns]

# %%
# 조건에 따른 column 추가,변경

df_t.loc[df_t['survived'] == 1, 'temp'] = 99999
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town     temp
# 0          True  Southampton      NaN
# 1         False    Cherbourg  99999.0
# 2         False  Southampton  99999.0
# 3         False  Southampton  99999.0
# 4          True  Southampton      NaN
# ..          ...          ...      ...
# 886        True  Southampton      NaN
# 887       False  Southampton  99999.0
# 888       False  Southampton      NaN
# 889        True    Cherbourg  99999.0
# 890        True   Queenstown      NaN
#
# [891 rows x 12 columns]

# %%
df_t['temp2'] = False

df_t.loc[df_t.age>30, 'temp2']
# Out:
# 1      False
# 3      False
# 4      False
# 6      False
# 11     False
#        ...
# 873    False
# 879    False
# 881    False
# 885    False
# 890    False
# Name: temp2, Length: 305, dtype: bool

# %%
df_t['temp'] = False
df_t.loc[df_t.age>30,'temp2'] = '30대 이상입니다'

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town   temp      temp2
# 0          True  Southampton  False      False
# 1         False    Cherbourg  False  30대 이상입니다
# 2         False  Southampton  False      False
# 3         False  Southampton  False  30대 이상입니다
# 4          True  Southampton  False  30대 이상입니다
# ..          ...          ...    ...        ...
# 886        True  Southampton  False      False
# 887       False  Southampton  False      False
# 888       False  Southampton  False      False
# 889        True    Cherbourg  False      False
# 890        True   Queenstown  False  30대 이상입니다
#
# [891 rows x 13 columns]

# %%
# 데이터 프레임으로 접근하여 값을 대입하면 오류가 남
# 데이터 프레임 접근은 복사본이므로 데이터에 직접 접근할 때에는 loc를 써야함 

df_t[df_t['age']>30]['temp2'] = True
# Out:
# <ipython-input-20-fa91d343b25b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t[df_t['age']>30]['temp2'] = True

# %%
df_t[df_t['age']>30].temp2
# Out:
# 1      30대 이상입니다
# 3      30대 이상입니다
# 4      30대 이상입니다
# 6      30대 이상입니다
# 11     30대 이상입니다
#          ...
# 873    30대 이상입니다
# 879    30대 이상입니다
# 881    30대 이상입니다
# 885    30대 이상입니다
# 890    30대 이상입니다
# Name: temp2, Length: 305, dtype: object

# %%
df_t.drop(columns=['temp','temp2'], inplace=True)

# %%
# np.where()

# 데이터 프레임 or 리스트 내 필드에 접근하고 수정하는 방법. (loc or iloc를 두번 사용하는 것과 동일)
# np.where(condition, x, y)는 조건이 충족되면x를, 그렇지 않으면y를 반환합니다.

# %%
df_t['alive'] = np.where(df_t['survived'] == 1, 'Yes','No')
df_t.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male  embark_town alive
# 0        True  Southampton    No
# 1       False    Cherbourg   Yes
# 2       False  Southampton   Yes
# 3       False  Southampton   Yes
# 4        True  Southampton    No

# %%
# np.select()

# 데이터 프레임 or 리스트 내 필드에 접근하고 수정하는 방법
# 조건 목록과 선택 목록을 입력으로 받아서 조건에 따라 선택 목록의 요소로 구성된 배열을 반환합니다. 
# 이 방법을 사용하면 두 개 이상의 조건이있을 때 Pandas의 주어진 조건을 기반으로 DataFrame 열을 만들 수 있습니다.

# %%
conditionlist = [
    (df_t['age'] >= 19) ,
    (df_t['age'] >= 8) & (df_t['age'] <19),
    df_t['age'] < 8]
choicelist = ['성인', '초중고등학생', '미취학아동']

df_t['status'] = np.select(conditionlist, choicelist,default='Not_Specified')

df_t.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town alive         status
# 0        True  Southampton    No             성인
# 1       False    Cherbourg   Yes             성인
# 2       False  Southampton   Yes             성인
# 3       False  Southampton   Yes             성인
# 4        True  Southampton    No             성인
# 5        True   Queenstown    No  Not_Specified
# 6        True  Southampton    No             성인
# 7       False  Southampton    No          미취학아동
# 8       False  Southampton   Yes             성인
# 9       False    Cherbourg   Yes         초중고등학생
